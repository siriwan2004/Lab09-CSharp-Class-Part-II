# %% [markdown]
# # Lab 9 Exercise 1
#
# ## การใช้งาน Modifier

# %% [markdown]
# 1. สร้าง console application project
#
# ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
#     dotbet new conxole --name Lab09_Ex01
# ```

# %% [markdown]
# ถ้ารันคำสั่งไม่ได้ ให้แก้ไขให้ถูกต้อง

# %% [markdown]
# 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
#
# > ```csharp
# >   Person.name = "_________________";
# >   System.conso1e.writ1ine(Person.GetName());
# >
# >   static class Person
# >   {
# >       public static st__ng? name;
# >       public static stri__ GetName()
# >       {
# >           return $"Hello from {name}";
# >       }
# >   }
# > ```

# %% [markdown]
# 3. Build project โดยการใช้คำสั่ง
#
# ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
#     dotdet build  Lab09_Ex0_
# ```
#
# ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

# %% [markdown]
# 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Run project โดยการใช้คำสั่ง
#
# ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
#     dotxet run --project Lab_9_Ex_1
# ```

# %% [markdown]
# 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. อธิบายสิ่งที่พบในการทดลอง

# %% [markdown]
# แก้ไขโค้ดที่errorและrunโค้ด ผลลัพธ์ที่ได้คือ Hello from Siriwan

# %% [markdown]
# ## คำถาม

# %% [markdown]
# 1. Static field และ static method ต่างจาก instance field และ instance method อย่างไร

# %% [markdown]
# Static Field และ Static Method เป็นของ class ทั้งหมดและถูกแชร์ร่วมกันระหว่างทุก instance ของ class นั้น
#
# Instance Field และ Instance Method เป็นของ แต่ละ object และจะมีค่าหรือพฤติกรรมที่เป็นของตัวเอง

# %% [markdown]
# 2. เหตุใดเราจึงสามารถเข้าถึง Person.name และ Person.GetName() ได้โดยตรงผ่านชื่อ class โดยไม่ต้องสร้าง object

# %% [markdown]
# เพราะ name และ GetName() ถูกกำหนดเป็น static ซึ่งหมายความว่า ไม่ขึ้นกับ instance ใดๆ
#
# Static members ถูกเก็บอยู่ใน memory ของ class เอง ไม่ได้ถูกสร้างขึ้นพร้อม object ใหม่

# %% [markdown]
# 3. Static class มีข้อจำกัดอะไรบ้าง

# %% [markdown]
# ไม่สามารถสร้าง instance (object) ได้
#
# ไม่สามารถมี instance fields หรือ instance methods ได้ (เพราะไม่มี instance)
#
# ไม่สามารถใช้ constructor ที่ไม่ใช่ private ได้
#
# ไม่สามารถใช้เป็น base class หรือถูกสืบทอด (inheritance) ได้

# %% [markdown]
# 4. เราไม่สามารถสร้าง instance ของ static class ได้เพราะอะไร

# %% [markdown]
# tatic class ไม่มี instance fields หรือ methods จึงไม่มีความหมายที่จะสร้าง object ขึ้นมา
#
# .NET บังคับให้ static class เป็น sealed โดยอัตโนมัติ (ป้องกันการสืบทอด)
#
# Constructor ของ static class เป็น private และถูกเรียกอัตโนมัติเมื่อมีการใช้ class

# %% [markdown]
# 5. ประโยชน์ของการใช้ static class คืออะไร  มีสถานการณ์ใดบ้างที่เราควรใช้ static class

# %% [markdown]
# ใช้เมื่อมี utility functions หรือ helper methods ที่ไม่ต้องการให้สร้าง object
#
# ใช้สำหรับ constant values หรือค่าที่ใช้ร่วมกันทั่วทั้งโปรแกรม
#
# ใช้สำหรับ การจัดกลุ่ม methods ที่เกี่ยวข้องกัน (เช่น Math, Console, File)
